# %% [markdown]
# # Benchmark Visualization Analysis - Tsh Test Runs
#
# This notebook demonstrates the enhanced visualization capabilities for LyoPRONTO benchmark analysis, including:
# - **Labeled heatmap annotations** showing "Scipy: X / Pyomo: Y" values with units
# - **Inverted objective difference colormap** (Blues_r: smaller=white, larger=dark blue)
# - **Dynamic method handling** that scales to arbitrary number of Pyomo discretization methods
#
# We'll analyze Tsh optimization benchmark results and display all visualization types.

# %% [markdown]
# ## 1. Import Required Libraries
